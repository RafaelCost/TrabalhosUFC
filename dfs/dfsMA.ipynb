# %%
import time
import numpy as np

def dfs(graph, state, maxVariables, e):
    stack = [e]
    time = 1
    lenGraph = len(graph)
    
    for l in range(lenGraph):
        
        if state[l][0] == 0:
            while len(stack) > 0:
                n = stack.pop()
                if state[n][0] == 0:
                    state[n][1] = time
                    state[n][0] = 1
                    time += 1

                stack.append(n)
                contTotal = 0
                contNoWhite = 0
                
                for j in range(0,lenGraph):
                    if graph[n][j] == 1:
                        contTotal +=1
                        if state[j][0] == 0:
                            stack.append(j)
                            break 
                        else:
                            contNoWhite+=1
                            
                if contTotal == contNoWhite:
                    stack.pop()    
                    state[n][0] = 2
                    state[n][2] = time
                    time+=1 
                
                
        if state[maxVariable[l][1]][0] != 2:
            stack.append(maxVariable[l][1])

    return state   

name = ['\Grafo1_1000_12','\Grafo1_1000_31','\Grafo1_1000_59','\Grafo1_1000_83',
        '\Grafo2_2000_12','\Grafo2_2000_31','\Grafo2_2000_59','\Grafo2_2000_83',
        '\Grafo3_3000_12','\Grafo3_3000_31','\Grafo3_3000_59','\Grafo3_3000_83',
        '\Grafo4_4000_12','\Grafo4_4000_31','\Grafo4_4000_59','\Grafo4_4000_83',
        '\Grafo5_5000_12','\Grafo5_5000_31','\Grafo5_5000_59','\Grafo5_5000_83',
        '\Grafo6_10000_12','\Grafo6_10000_31','\Grafo6_10000_59']

for y in name:
    print("")
    print("Inicializando o arquivo . . .")
    iniL = time.time()
    end = 'trabTestes'+y+'.txt'
    text = open(end,'r').readlines()
    length = int(text[0].split(' ')[0])
    text = text[2:]


    graph = []
    for p in range(length):
        graph.append(0)
        graph[p]=[]
        for i in range(length):
            graph[p].append(0)

    adjMatrix = graph

    
    maxVariable=[]
    for j in range(length):
        maxVariable.append(0)
        maxVariable[j] = []
        for i in range(2):
            maxVariable[j].append(0)

    def startAdj(x):
        for p in range(len(x)):
            pos = x[p].split(' ')
            
            if int(pos[0]) != int(pos[1]):
                adjMatrix[int(pos[0])][int(pos[1])] = 1
            maxVariable[int(pos[0])][0] += 1
            maxVariable[int(pos[1])][0] += 1     
            maxVariable[int(pos[0])][1] = int(pos[0])
            maxVariable[int(pos[1])][1] = int(pos[1]) 


    startAdj(text)
    maxVariable.sort(reverse=True)
    m =maxVariable[0][1]

    state=[]
    for j in range(length):
        state.append(0)
        state[j] = []
        for i in range(3):
            state[j].append(0)


    fimL = time.time()
    print("")
    print("Tempo de Leitura:", fimL-iniL)
    print("")
    print("Vertice Inicial:",m)
    print()
    print("Inicializando a busca no grafo "+y+' . . .')

    iniE = time.time()
    k = dfs(adjMatrix, state, maxVariable, m)
    fimE = time.time()

    print("")
    print("Busca finalizada no grafo "+y+' . . .')
    print("")
    print("Tempo da Busca no grafo "+y+': ',fimE-iniE)
    print()

    arq = open('resultados\Matriz de Adjacencia'+y+'.txt', 'w')
    arq.write("Tempo de Leitura: "+str(fimL-iniL))
    arq.writelines("\n")
    arq.writelines("\n")
    arq.writelines("Vertice Inicial: "+str(m))
    arq.writelines("\n")
    arq.writelines("\n")
    arq.writelines("Tempo da Busca: "+str(fimE-iniE))
    arq.writelines("\n")
    arq.writelines("\n")
    print("")
    print("")
  
    for p in range(len(k)):
        arq.writelines(str(p)+": ("+str(k[p][1])+"/"+str(k[p][2])+")")
        arq.writelines("\n")
# Out:
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 0.5598423480987549
#
# Vertice Inicial: 649
#
# Inicializando a busca no grafo \Grafo1_1000_12 . . .
#
# Busca finalizada no grafo \Grafo1_1000_12 . . .
#
# Tempo da Busca no grafo \Grafo1_1000_12:  0.1057591438293457
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 1.0289051532745361
#
# Vertice Inicial: 15
#
# Inicializando a busca no grafo \Grafo1_1000_31 . . .
#
# Busca finalizada no grafo \Grafo1_1000_31 . . .
#
# Tempo da Busca no grafo \Grafo1_1000_31:  0.13618111610412598
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 1.8636562824249268
#
# Vertice Inicial: 358
#
# Inicializando a busca no grafo \Grafo1_1000_59 . . .
#
# Busca finalizada no grafo \Grafo1_1000_59 . . .
#
# Tempo da Busca no grafo \Grafo1_1000_59:  0.17617440223693848
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 2.5532939434051514
#
# Vertice Inicial: 106
#
# Inicializando a busca no grafo \Grafo1_1000_83 . . .
#
# Busca finalizada no grafo \Grafo1_1000_83 . . .
#
# Tempo da Busca no grafo \Grafo1_1000_83:  0.2250347137451172
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 2.0142905712127686
#
# Vertice Inicial: 52
#
# Inicializando a busca no grafo \Grafo2_2000_12 . . .
#
# Busca finalizada no grafo \Grafo2_2000_12 . . .
#
# Tempo da Busca no grafo \Grafo2_2000_12:  0.44484758377075195
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 4.258517503738403
#
# Vertice Inicial: 1039
#
# Inicializando a busca no grafo \Grafo2_2000_31 . . .
#
# Busca finalizada no grafo \Grafo2_2000_31 . . .
#
# Tempo da Busca no grafo \Grafo2_2000_31:  0.5646853446960449
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 7.6055285930633545
#
# Vertice Inicial: 1657
#
# Inicializando a busca no grafo \Grafo2_2000_59 . . .
#
# Busca finalizada no grafo \Grafo2_2000_59 . . .
#
# Tempo da Busca no grafo \Grafo2_2000_59:  0.8152830600738525
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 10.405137062072754
#
# Vertice Inicial: 407
#
# Inicializando a busca no grafo \Grafo2_2000_83 . . .
#
# Busca finalizada no grafo \Grafo2_2000_83 . . .
#
# Tempo da Busca no grafo \Grafo2_2000_83:  0.8595306873321533
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 4.773242473602295
#
# Vertice Inicial: 2383
#
# Inicializando a busca no grafo \Grafo3_3000_12 . . .
#
# Busca finalizada no grafo \Grafo3_3000_12 . . .
#
# Tempo da Busca no grafo \Grafo3_3000_12:  1.050330400466919
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 9.960540056228638
#
# Vertice Inicial: 2592
#
# Inicializando a busca no grafo \Grafo3_3000_31 . . .
#
# Busca finalizada no grafo \Grafo3_3000_31 . . .
#
# Tempo da Busca no grafo \Grafo3_3000_31:  1.2498202323913574
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 17.617894411087036
#
# Vertice Inicial: 933
#
# Inicializando a busca no grafo \Grafo3_3000_59 . . .
#
# Busca finalizada no grafo \Grafo3_3000_59 . . .
#
# Tempo da Busca no grafo \Grafo3_3000_59:  1.687032699584961
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 23.80980634689331
#
# Vertice Inicial: 975
#
# Inicializando a busca no grafo \Grafo3_3000_83 . . .
#
# Busca finalizada no grafo \Grafo3_3000_83 . . .
#
# Tempo da Busca no grafo \Grafo3_3000_83:  2.0236921310424805
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 8.54780912399292
#
# Vertice Inicial: 695
#
# Inicializando a busca no grafo \Grafo4_4000_12 . . .
#
# Busca finalizada no grafo \Grafo4_4000_12 . . .
#
# Tempo da Busca no grafo \Grafo4_4000_12:  1.7944884300231934
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 17.760044813156128
#
# Vertice Inicial: 3294
#
# Inicializando a busca no grafo \Grafo4_4000_31 . . .
#
# Busca finalizada no grafo \Grafo4_4000_31 . . .
#
# Tempo da Busca no grafo \Grafo4_4000_31:  2.6088407039642334
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 33.47126364707947
#
# Vertice Inicial: 1735
#
# Inicializando a busca no grafo \Grafo4_4000_59 . . .
#
# Busca finalizada no grafo \Grafo4_4000_59 . . .
#
# Tempo da Busca no grafo \Grafo4_4000_59:  3.009657621383667
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 45.091742753982544
#
# Vertice Inicial: 2372
#
# Inicializando a busca no grafo \Grafo4_4000_83 . . .
#
# Busca finalizada no grafo \Grafo4_4000_83 . . .
#
# Tempo da Busca no grafo \Grafo4_4000_83:  3.682690382003784
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 13.135845184326172
#
# Vertice Inicial: 540
#
# Inicializando a busca no grafo \Grafo5_5000_12 . . .
#
# Busca finalizada no grafo \Grafo5_5000_12 . . .
#
# Tempo da Busca no grafo \Grafo5_5000_12:  2.7163617610931396
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 25.96917700767517
#
# Vertice Inicial: 4551
#
# Inicializando a busca no grafo \Grafo5_5000_31 . . .
#
# Busca finalizada no grafo \Grafo5_5000_31 . . .
#
# Tempo da Busca no grafo \Grafo5_5000_31:  3.492202043533325
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 46.436636209487915
#
# Vertice Inicial: 3617
#
# Inicializando a busca no grafo \Grafo5_5000_59 . . .
#
# Busca finalizada no grafo \Grafo5_5000_59 . . .
#
# Tempo da Busca no grafo \Grafo5_5000_59:  4.560455799102783
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 63.903905153274536
#
# Vertice Inicial: 3975
#
# Inicializando a busca no grafo \Grafo5_5000_83 . . .
#
# Busca finalizada no grafo \Grafo5_5000_83 . . .
#
# Tempo da Busca no grafo \Grafo5_5000_83:  5.4099037647247314
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 54.66434121131897
#
# Vertice Inicial: 8544
#
# Inicializando a busca no grafo \Grafo6_10000_12 . . .
#
# Busca finalizada no grafo \Grafo6_10000_12 . . .
#
# Tempo da Busca no grafo \Grafo6_10000_12:  11.65223503112793
#
#
#
#
# Inicializando o arquivo . . .
#
# Tempo de Leitura: 111.89632868766785
#
# Vertice Inicial: 6978
#
# Inicializando a busca no grafo \Grafo6_10000_31 . . .
#
# Busca finalizada no grafo \Grafo6_10000_31 . . .
#
# Tempo da Busca no grafo \Grafo6_10000_31:  14.177289009094238
#
#
#
#
# Inicializando o arquivo . . .
